# %% [markdown]
# ## Import du dataset et division en données normales / anormales

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, LSTM, RepeatVector, TimeDistributed, Dense
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# 2024-12-17 11:25:23.494406: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-12-17 11:25:23.515469: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-12-17 11:25:23.521642: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-12-17 11:25:23.536806: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-12-17 11:25:28.159976: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Vérifier si TensorFlow détecte un GPU
if tf.config.list_physical_devices('GPU'):
    print("Il y a un GPU prêt à être utilisé.") 
else:
    print("Aucun GPU n'est disponible.")
# Out:
# Il y a un GPU prêt à être utilisé.

# %%
import pandas as pd
import glob
import os

# Chemin vers le dossier contenant les fichiers .h5
dataset_path = "./Dataset"

# Liste de tous les fichiers .h5 dans le dossier
h5_files = glob.glob(os.path.join(dataset_path, "*.h5"))

# Listes pour stocker les DataFrames normaux et anormaux
normal_data_frames = []
anomaly_data_frames = []

# Charger chaque fichier .h5 dans un DataFrame et le classer
for file in h5_files:
    try:
        df = pd.read_hdf(file)
        
        # Identifier les fichiers anormaux par la présence de mots-clés dans le nom du fichier
        if "shift_on" in file:
            anomaly_data_frames.append(df)
            print(f"{file} classé comme anomalie.")
        else:
            normal_data_frames.append(df)
            print(f"{file} classé comme normal.")
            
    except Exception as e:
        print(f"Erreur lors du chargement de {file}: {e}")
# Out:
# ./Dataset/TimeSeries_Scenario_00001_ScenarioInstanceRandint_id_0001.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00001_ScenarioInstanceRandint_id_0001_shift_on___flight_director_pitch__flight_director_roll.h5 classé comme anomalie.
# ./Dataset/TimeSeries_Scenario_00002_ScenarioInstanceRandint_id_0002.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00003_ScenarioInstanceRandint_id_0003.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00004_ScenarioInstanceRandint_id_0004.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00005_ScenarioInstanceRandint_id_0005.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00006_ScenarioInstanceRandint_id_0006.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00006_ScenarioInstanceRandint_id_0006_shift_on___flight_director_pitch__flight_director_roll.h5 classé comme anomalie.
# ./Dataset/TimeSeries_Scenario_00007_ScenarioInstanceRandint_id_0007.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00008_ScenarioInstanceRandint_id_0008.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00009_ScenarioInstanceRandint_id_0009.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00010_ScenarioInstanceRandint_id_0010.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00011_ScenarioInstanceRandint_id_0011.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00012_ScenarioInstanceRandint_id_0012.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00013_ScenarioInstanceRandint_id_0013.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00013_ScenarioInstanceRandint_id_0013_shift_on___flight_director_pitch__flight_director_roll.h5 classé comme anomalie.
# ./Dataset/TimeSeries_Scenario_00014_ScenarioInstanceRandint_id_0014.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00015_ScenarioInstanceRandint_id_0015.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00016_ScenarioInstanceRandint_id_0016.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00016_ScenarioInstanceRandint_id_0016_shift_on___flight_director_pitch__flight_director_roll.h5 classé comme anomalie.
# ./Dataset/TimeSeries_Scenario_00017_ScenarioInstanceRandint_id_0017.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00018_ScenarioInstanceRandint_id_0018.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00019_ScenarioInstanceRandint_id_0019.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00019_ScenarioInstanceRandint_id_0019_shift_on___flight_director_pitch__flight_director_roll.h5 classé comme anomalie.
# ./Dataset/TimeSeries_Scenario_00020_ScenarioInstanceRandint_id_0020.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00021_ScenarioInstanceRandint_id_0021.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00022_ScenarioInstanceRandint_id_0022.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00023_ScenarioInstanceRandint_id_0023.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00024_ScenarioInstanceRandint_id_0024.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00025_ScenarioInstanceRandint_id_0025.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00026_ScenarioInstanceRandint_id_0026.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00027_ScenarioInstanceRandint_id_0027.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00028_ScenarioInstanceRandint_id_0028.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00029_ScenarioInstanceRandint_id_0029.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00030_ScenarioInstanceRandint_id_0030.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00031_ScenarioInstanceRandint_id_0031.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00032_ScenarioInstanceRandint_id_0032.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00033_ScenarioInstanceRandint_id_0033.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00034_ScenarioInstanceRandint_id_0034.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00035_ScenarioInstanceRandint_id_0035.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00036_ScenarioInstanceRandint_id_0036.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00037_ScenarioInstanceRandint_id_0037.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00038_ScenarioInstanceRandint_id_0038.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00039_ScenarioInstanceRandint_id_0039.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00040_ScenarioInstanceRandint_id_0040.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00041_ScenarioInstanceRandint_id_0041.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00042_ScenarioInstanceRandint_id_0042.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00043_ScenarioInstanceRandint_id_0043.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00043_ScenarioInstanceRandint_id_0043_shift_on___flight_director_pitch__flight_director_roll.h5 classé comme anomalie.
# ./Dataset/TimeSeries_Scenario_00044_ScenarioInstanceRandint_id_0044.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00045_ScenarioInstanceRandint_id_0045.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00046_ScenarioInstanceRandint_id_0046.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00047_ScenarioInstanceRandint_id_0047.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00047_ScenarioInstanceRandint_id_0047_shift_on___flight_director_pitch__flight_director_roll.h5 classé comme anomalie.
# ./Dataset/TimeSeries_Scenario_00048_ScenarioInstanceRandint_id_0048.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00049_ScenarioInstanceRandint_id_0049.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00050_ScenarioInstanceRandint_id_0050.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00051_ScenarioInstanceRandint_id_0051.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00052_ScenarioInstanceRandint_id_0052.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00053_ScenarioInstanceRandint_id_0053.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00054_ScenarioInstanceRandint_id_0054.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00055_ScenarioInstanceRandint_id_0055.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00056_ScenarioInstanceRandint_id_0056.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00057_ScenarioInstanceRandint_id_0057.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00058_ScenarioInstanceRandint_id_0058.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00059_ScenarioInstanceRandint_id_0059.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00060_ScenarioInstanceRandint_id_0060.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00061_ScenarioInstanceRandint_id_0061.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00062_ScenarioInstanceRandint_id_0062.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00063_ScenarioInstanceRandint_id_0063.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00064_ScenarioInstanceRandint_id_0064.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00065_ScenarioInstanceRandint_id_0065.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00066_ScenarioInstanceRandint_id_0066.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00067_ScenarioInstanceRandint_id_0067.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00068_ScenarioInstanceRandint_id_0068.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00069_ScenarioInstanceRandint_id_0069.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00070_ScenarioInstanceRandint_id_0070.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00071_ScenarioInstanceRandint_id_0071.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00072_ScenarioInstanceRandint_id_0072.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00073_ScenarioInstanceRandint_id_0073.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00074_ScenarioInstanceRandint_id_0074.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00075_ScenarioInstanceRandint_id_0075.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00076_ScenarioInstanceRandint_id_0076.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00076_ScenarioInstanceRandint_id_0076_shift_on___flight_director_pitch__flight_director_roll.h5 classé comme anomalie.
# ./Dataset/TimeSeries_Scenario_00077_ScenarioInstanceRandint_id_0077.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00078_ScenarioInstanceRandint_id_0078.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00079_ScenarioInstanceRandint_id_0079.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00080_ScenarioInstanceRandint_id_0080.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00081_ScenarioInstanceRandint_id_0081.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00082_ScenarioInstanceRandint_id_0082.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00083_ScenarioInstanceRandint_id_0083.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00083_ScenarioInstanceRandint_id_0083_shift_on___flight_director_pitch__flight_director_roll.h5 classé comme anomalie.
# ./Dataset/TimeSeries_Scenario_00084_ScenarioInstanceRandint_id_0084.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00085_ScenarioInstanceRandint_id_0085.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00086_ScenarioInstanceRandint_id_0086.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00087_ScenarioInstanceRandint_id_0087.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00088_ScenarioInstanceRandint_id_0088.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00089_ScenarioInstanceRandint_id_0089.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00090_ScenarioInstanceRandint_id_0090.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00091_ScenarioInstanceRandint_id_0091.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00092_ScenarioInstanceRandint_id_0092.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00093_ScenarioInstanceRandint_id_0093.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00094_ScenarioInstanceRandint_id_0094.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00095_ScenarioInstanceRandint_id_0095.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00096_ScenarioInstanceRandint_id_0096.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00097_ScenarioInstanceRandint_id_0097.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00098_ScenarioInstanceRandint_id_0098.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00099_ScenarioInstanceRandint_id_0099.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00099_ScenarioInstanceRandint_id_0099_shift_on___flight_director_pitch__flight_director_roll.h5 classé comme anomalie.
# ./Dataset/TimeSeries_Scenario_00100_ScenarioInstanceRandint_id_0100.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00101_ScenarioInstanceRandint_id_0101.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00102_ScenarioInstanceRandint_id_0102.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00103_ScenarioInstanceRandint_id_0103.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00104_ScenarioInstanceRandint_id_0104.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00105_ScenarioInstanceRandint_id_0105.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00106_ScenarioInstanceRandint_id_0106.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00107_ScenarioInstanceRandint_id_0107.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00108_ScenarioInstanceRandint_id_0108.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00109_ScenarioInstanceRandint_id_0109.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00110_ScenarioInstanceRandint_id_0110.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00111_ScenarioInstanceRandint_id_0111.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00112_ScenarioInstanceRandint_id_0112.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00112_ScenarioInstanceRandint_id_0112_shift_on___flight_director_pitch__flight_director_roll.h5 classé comme anomalie.
# ./Dataset/TimeSeries_Scenario_00113_ScenarioInstanceRandint_id_0113.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00114_ScenarioInstanceRandint_id_0114.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00115_ScenarioInstanceRandint_id_0115.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00116_ScenarioInstanceRandint_id_0116.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00117_ScenarioInstanceRandint_id_0117.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00118_ScenarioInstanceRandint_id_0118.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00119_ScenarioInstanceRandint_id_0119.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00120_ScenarioInstanceRandint_id_0120.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00121_ScenarioInstanceRandint_id_0121.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00122_ScenarioInstanceRandint_id_0122.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00123_ScenarioInstanceRandint_id_0123.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00124_ScenarioInstanceRandint_id_0124.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00125_ScenarioInstanceRandint_id_0125.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00126_ScenarioInstanceRandint_id_0126.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00127_ScenarioInstanceRandint_id_0127.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00128_ScenarioInstanceRandint_id_0128.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00129_ScenarioInstanceRandint_id_0129.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00130_ScenarioInstanceRandint_id_0130.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00131_ScenarioInstanceRandint_id_0131.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00132_ScenarioInstanceRandint_id_0132.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00133_ScenarioInstanceRandint_id_0133.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00134_ScenarioInstanceRandint_id_0134.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00135_ScenarioInstanceRandint_id_0135.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00136_ScenarioInstanceRandint_id_0136.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00137_ScenarioInstanceRandint_id_0137.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00138_ScenarioInstanceRandint_id_0138.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00139_ScenarioInstanceRandint_id_0139.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00140_ScenarioInstanceRandint_id_0140.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00141_ScenarioInstanceRandint_id_0141.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00142_ScenarioInstanceRandint_id_0142.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00143_ScenarioInstanceRandint_id_0143.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00144_ScenarioInstanceRandint_id_0144.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00145_ScenarioInstanceRandint_id_0145.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00146_ScenarioInstanceRandint_id_0146.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00147_ScenarioInstanceRandint_id_0147.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00148_ScenarioInstanceRandint_id_0148.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00149_ScenarioInstanceRandint_id_0149.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00150_ScenarioInstanceRandint_id_0150.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00151_ScenarioInstanceRandint_id_0151.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00152_ScenarioInstanceRandint_id_0152.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00153_ScenarioInstanceRandint_id_0153.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00154_ScenarioInstanceRandint_id_0154.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00155_ScenarioInstanceRandint_id_0155.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00156_ScenarioInstanceRandint_id_0156.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00157_ScenarioInstanceRandint_id_0157.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00158_ScenarioInstanceRandint_id_0158.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00159_ScenarioInstanceRandint_id_0159.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00160_ScenarioInstanceRandint_id_0160.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00161_ScenarioInstanceRandint_id_0161.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00162_ScenarioInstanceRandint_id_0162.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00163_ScenarioInstanceRandint_id_0163.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00164_ScenarioInstanceRandint_id_0164.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00164_ScenarioInstanceRandint_id_0164_shift_on___flight_director_pitch__flight_director_roll.h5 classé comme anomalie.
# ./Dataset/TimeSeries_Scenario_00165_ScenarioInstanceRandint_id_0165.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00166_ScenarioInstanceRandint_id_0166.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00167_ScenarioInstanceRandint_id_0167.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00168_ScenarioInstanceRandint_id_0168.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00169_ScenarioInstanceRandint_id_0169.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00170_ScenarioInstanceRandint_id_0170.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00171_ScenarioInstanceRandint_id_0171.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00172_ScenarioInstanceRandint_id_0172.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00173_ScenarioInstanceRandint_id_0173.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00174_ScenarioInstanceRandint_id_0174.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00175_ScenarioInstanceRandint_id_0175.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00176_ScenarioInstanceRandint_id_0176.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00177_ScenarioInstanceRandint_id_0177.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00178_ScenarioInstanceRandint_id_0178.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00179_ScenarioInstanceRandint_id_0179.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00180_ScenarioInstanceRandint_id_0180.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00181_ScenarioInstanceRandint_id_0181.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00182_ScenarioInstanceRandint_id_0182.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00183_ScenarioInstanceRandint_id_0183.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00184_ScenarioInstanceRandint_id_0184.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00185_ScenarioInstanceRandint_id_0185.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00186_ScenarioInstanceRandint_id_0186.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00187_ScenarioInstanceRandint_id_0187.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00188_ScenarioInstanceRandint_id_0188.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00189_ScenarioInstanceRandint_id_0189.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00190_ScenarioInstanceRandint_id_0190.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00191_ScenarioInstanceRandint_id_0191.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00192_ScenarioInstanceRandint_id_0192.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00193_ScenarioInstanceRandint_id_0193.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00194_ScenarioInstanceRandint_id_0194.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00195_ScenarioInstanceRandint_id_0195.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00196_ScenarioInstanceRandint_id_0196.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00197_ScenarioInstanceRandint_id_0197.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00198_ScenarioInstanceRandint_id_0198.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00199_ScenarioInstanceRandint_id_0199.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00200_ScenarioInstanceRandint_id_0200.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00201_ScenarioInstanceRandint_id_0201.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00202_ScenarioInstanceRandint_id_0202.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00203_ScenarioInstanceRandint_id_0203.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00204_ScenarioInstanceRandint_id_0204.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00205_ScenarioInstanceRandint_id_0205.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00206_ScenarioInstanceRandint_id_0206.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00207_ScenarioInstanceRandint_id_0207.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00208_ScenarioInstanceRandint_id_0208.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00209_ScenarioInstanceRandint_id_0209.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00210_ScenarioInstanceRandint_id_0210.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00211_ScenarioInstanceRandint_id_0211.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00212_ScenarioInstanceRandint_id_0212.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00213_ScenarioInstanceRandint_id_0213.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00214_ScenarioInstanceRandint_id_0214.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00215_ScenarioInstanceRandint_id_0215.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00216_ScenarioInstanceRandint_id_0216.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00217_ScenarioInstanceRandint_id_0217.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00218_ScenarioInstanceRandint_id_0218.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00219_ScenarioInstanceRandint_id_0219.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00220_ScenarioInstanceRandint_id_0220.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00221_ScenarioInstanceRandint_id_0221.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00222_ScenarioInstanceRandint_id_0222.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00223_ScenarioInstanceRandint_id_0223.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00224_ScenarioInstanceRandint_id_0224.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00224_ScenarioInstanceRandint_id_0224_shift_on___flight_director_pitch__flight_director_roll.h5 classé comme anomalie.
# ./Dataset/TimeSeries_Scenario_00225_ScenarioInstanceRandint_id_0225.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00226_ScenarioInstanceRandint_id_0226.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00227_ScenarioInstanceRandint_id_0227.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00228_ScenarioInstanceRandint_id_0228.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00229_ScenarioInstanceRandint_id_0229.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00230_ScenarioInstanceRandint_id_0230.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00231_ScenarioInstanceRandint_id_0231.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00232_ScenarioInstanceRandint_id_0232.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00233_ScenarioInstanceRandint_id_0233.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00234_ScenarioInstanceRandint_id_0234.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00235_ScenarioInstanceRandint_id_0235.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00236_ScenarioInstanceRandint_id_0236.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00237_ScenarioInstanceRandint_id_0237.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00238_ScenarioInstanceRandint_id_0238.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00239_ScenarioInstanceRandint_id_0239.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00240_ScenarioInstanceRandint_id_0240.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00241_ScenarioInstanceRandint_id_0241.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00242_ScenarioInstanceRandint_id_0242.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00243_ScenarioInstanceRandint_id_0243.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00244_ScenarioInstanceRandint_id_0244.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00245_ScenarioInstanceRandint_id_0245.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00246_ScenarioInstanceRandint_id_0246.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00247_ScenarioInstanceRandint_id_0247.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00248_ScenarioInstanceRandint_id_0248.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00249_ScenarioInstanceRandint_id_0249.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00250_ScenarioInstanceRandint_id_0250.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00251_ScenarioInstanceRandint_id_0251.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00252_ScenarioInstanceRandint_id_0252.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00253_ScenarioInstanceRandint_id_0253.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00254_ScenarioInstanceRandint_id_0254.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00255_ScenarioInstanceRandint_id_0255.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00256_ScenarioInstanceRandint_id_0256.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00257_ScenarioInstanceRandint_id_0257.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00258_ScenarioInstanceRandint_id_0258.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00259_ScenarioInstanceRandint_id_0259.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00260_ScenarioInstanceRandint_id_0260.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00261_ScenarioInstanceRandint_id_0261.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00262_ScenarioInstanceRandint_id_0262.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00263_ScenarioInstanceRandint_id_0263.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00264_ScenarioInstanceRandint_id_0264.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00265_ScenarioInstanceRandint_id_0265.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00266_ScenarioInstanceRandint_id_0266.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00267_ScenarioInstanceRandint_id_0267.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00268_ScenarioInstanceRandint_id_0268.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00269_ScenarioInstanceRandint_id_0269.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00270_ScenarioInstanceRandint_id_0270.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00271_ScenarioInstanceRandint_id_0271.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00272_ScenarioInstanceRandint_id_0272.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00273_ScenarioInstanceRandint_id_0273.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00274_ScenarioInstanceRandint_id_0274.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00275_ScenarioInstanceRandint_id_0275.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00276_ScenarioInstanceRandint_id_0276.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00277_ScenarioInstanceRandint_id_0277.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00278_ScenarioInstanceRandint_id_0278.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00279_ScenarioInstanceRandint_id_0279.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00280_ScenarioInstanceRandint_id_0280.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00281_ScenarioInstanceRandint_id_0281.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00282_ScenarioInstanceRandint_id_0282.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00283_ScenarioInstanceRandint_id_0283.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00284_ScenarioInstanceRandint_id_0284.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00285_ScenarioInstanceRandint_id_0285.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00286_ScenarioInstanceRandint_id_0286.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00287_ScenarioInstanceRandint_id_0287.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00288_ScenarioInstanceRandint_id_0288.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00289_ScenarioInstanceRandint_id_0289.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00290_ScenarioInstanceRandint_id_0290.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00291_ScenarioInstanceRandint_id_0291.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00292_ScenarioInstanceRandint_id_0292.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00293_ScenarioInstanceRandint_id_0293.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00294_ScenarioInstanceRandint_id_0294.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00295_ScenarioInstanceRandint_id_0295.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00296_ScenarioInstanceRandint_id_0296.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00297_ScenarioInstanceRandint_id_0297.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00298_ScenarioInstanceRandint_id_0298.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00299_ScenarioInstanceRandint_id_0299.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00300_ScenarioInstanceRandint_id_0300.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00301_ScenarioInstanceRandint_id_0301.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00302_ScenarioInstanceRandint_id_0302.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00303_ScenarioInstanceRandint_id_0303.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00304_ScenarioInstanceRandint_id_0304.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00305_ScenarioInstanceRandint_id_0305.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00306_ScenarioInstanceRandint_id_0306.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00307_ScenarioInstanceRandint_id_0307.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00308_ScenarioInstanceRandint_id_0308.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00309_ScenarioInstanceRandint_id_0309.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00310_ScenarioInstanceRandint_id_0310.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00311_ScenarioInstanceRandint_id_0311.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00312_ScenarioInstanceRandint_id_0312.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00313_ScenarioInstanceRandint_id_0313.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00314_ScenarioInstanceRandint_id_0314.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00315_ScenarioInstanceRandint_id_0315.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00316_ScenarioInstanceRandint_id_0316.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00317_ScenarioInstanceRandint_id_0317.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00318_ScenarioInstanceRandint_id_0318.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00319_ScenarioInstanceRandint_id_0319.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00320_ScenarioInstanceRandint_id_0320.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00321_ScenarioInstanceRandint_id_0321.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00322_ScenarioInstanceRandint_id_0322.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00323_ScenarioInstanceRandint_id_0323.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00324_ScenarioInstanceRandint_id_0324.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00325_ScenarioInstanceRandint_id_0325.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00326_ScenarioInstanceRandint_id_0326.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00327_ScenarioInstanceRandint_id_0327.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00328_ScenarioInstanceRandint_id_0328.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00329_ScenarioInstanceRandint_id_0329.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00330_ScenarioInstanceRandint_id_0330.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00331_ScenarioInstanceRandint_id_0331.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00332_ScenarioInstanceRandint_id_0332.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00333_ScenarioInstanceRandint_id_0333.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00334_ScenarioInstanceRandint_id_0334.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00334_ScenarioInstanceRandint_id_0334_shift_on___flight_director_pitch__flight_director_roll.h5 classé comme anomalie.
# ./Dataset/TimeSeries_Scenario_00335_ScenarioInstanceRandint_id_0335.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00336_ScenarioInstanceRandint_id_0336.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00337_ScenarioInstanceRandint_id_0337.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00338_ScenarioInstanceRandint_id_0338.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00339_ScenarioInstanceRandint_id_0339.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00340_ScenarioInstanceRandint_id_0340.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00341_ScenarioInstanceRandint_id_0341.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00342_ScenarioInstanceRandint_id_0342.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00343_ScenarioInstanceRandint_id_0343.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00344_ScenarioInstanceRandint_id_0344.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00345_ScenarioInstanceRandint_id_0345.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00346_ScenarioInstanceRandint_id_0346.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00347_ScenarioInstanceRandint_id_0347.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00348_ScenarioInstanceRandint_id_0348.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00349_ScenarioInstanceRandint_id_0349.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00350_ScenarioInstanceRandint_id_0350.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00351_ScenarioInstanceRandint_id_0351.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00352_ScenarioInstanceRandint_id_0352.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00353_ScenarioInstanceRandint_id_0353.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00354_ScenarioInstanceRandint_id_0354.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00355_ScenarioInstanceRandint_id_0355.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00356_ScenarioInstanceRandint_id_0356.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00357_ScenarioInstanceRandint_id_0357.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00358_ScenarioInstanceRandint_id_0358.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00359_ScenarioInstanceRandint_id_0359.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00360_ScenarioInstanceRandint_id_0360.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00361_ScenarioInstanceRandint_id_0361.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00362_ScenarioInstanceRandint_id_0362.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00363_ScenarioInstanceRandint_id_0363.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00364_ScenarioInstanceRandint_id_0364.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00365_ScenarioInstanceRandint_id_0365.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00366_ScenarioInstanceRandint_id_0366.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00367_ScenarioInstanceRandint_id_0367.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00368_ScenarioInstanceRandint_id_0368.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00369_ScenarioInstanceRandint_id_0369.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00370_ScenarioInstanceRandint_id_0370.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00371_ScenarioInstanceRandint_id_0371.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00372_ScenarioInstanceRandint_id_0372.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00373_ScenarioInstanceRandint_id_0373.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00374_ScenarioInstanceRandint_id_0374.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00375_ScenarioInstanceRandint_id_0375.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00376_ScenarioInstanceRandint_id_0376.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00377_ScenarioInstanceRandint_id_0377.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00378_ScenarioInstanceRandint_id_0378.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00379_ScenarioInstanceRandint_id_0379.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00380_ScenarioInstanceRandint_id_0380.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00381_ScenarioInstanceRandint_id_0381.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00382_ScenarioInstanceRandint_id_0382.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00383_ScenarioInstanceRandint_id_0383.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00383_ScenarioInstanceRandint_id_0383_shift_on___flight_director_pitch__flight_director_roll.h5 classé comme anomalie.
# ./Dataset/TimeSeries_Scenario_00384_ScenarioInstanceRandint_id_0384.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00385_ScenarioInstanceRandint_id_0385.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00386_ScenarioInstanceRandint_id_0386.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00387_ScenarioInstanceRandint_id_0387.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00388_ScenarioInstanceRandint_id_0388.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00389_ScenarioInstanceRandint_id_0389.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00390_ScenarioInstanceRandint_id_0390.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00391_ScenarioInstanceRandint_id_0391.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00392_ScenarioInstanceRandint_id_0392.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00393_ScenarioInstanceRandint_id_0393.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00394_ScenarioInstanceRandint_id_0394.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00395_ScenarioInstanceRandint_id_0395.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00396_ScenarioInstanceRandint_id_0396.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00397_ScenarioInstanceRandint_id_0397.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00398_ScenarioInstanceRandint_id_0398.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00399_ScenarioInstanceRandint_id_0399.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00400_ScenarioInstanceRandint_id_0400.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00401_ScenarioInstanceRandint_id_0401.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00402_ScenarioInstanceRandint_id_0402.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00403_ScenarioInstanceRandint_id_0403.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00404_ScenarioInstanceRandint_id_0404.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00405_ScenarioInstanceRandint_id_0405.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00406_ScenarioInstanceRandint_id_0406.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00407_ScenarioInstanceRandint_id_0407.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00408_ScenarioInstanceRandint_id_0408.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00409_ScenarioInstanceRandint_id_0409.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00410_ScenarioInstanceRandint_id_0410.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00411_ScenarioInstanceRandint_id_0411.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00412_ScenarioInstanceRandint_id_0412.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00413_ScenarioInstanceRandint_id_0413.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00414_ScenarioInstanceRandint_id_0414.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00415_ScenarioInstanceRandint_id_0415.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00416_ScenarioInstanceRandint_id_0416.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00417_ScenarioInstanceRandint_id_0417.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00418_ScenarioInstanceRandint_id_0418.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00419_ScenarioInstanceRandint_id_0419.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00420_ScenarioInstanceRandint_id_0420.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00421_ScenarioInstanceRandint_id_0421.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00422_ScenarioInstanceRandint_id_0422.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00423_ScenarioInstanceRandint_id_0423.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00424_ScenarioInstanceRandint_id_0424.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00424_ScenarioInstanceRandint_id_0424_shift_on___flight_director_pitch__flight_director_roll.h5 classé comme anomalie.
# ./Dataset/TimeSeries_Scenario_00425_ScenarioInstanceRandint_id_0425.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00426_ScenarioInstanceRandint_id_0426.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00427_ScenarioInstanceRandint_id_0427.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00428_ScenarioInstanceRandint_id_0428.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00429_ScenarioInstanceRandint_id_0429.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00430_ScenarioInstanceRandint_id_0430.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00431_ScenarioInstanceRandint_id_0431.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00432_ScenarioInstanceRandint_id_0432.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00433_ScenarioInstanceRandint_id_0433.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00434_ScenarioInstanceRandint_id_0434.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00435_ScenarioInstanceRandint_id_0435.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00436_ScenarioInstanceRandint_id_0436.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00437_ScenarioInstanceRandint_id_0437.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00438_ScenarioInstanceRandint_id_0438.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00439_ScenarioInstanceRandint_id_0439.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00440_ScenarioInstanceRandint_id_0440.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00441_ScenarioInstanceRandint_id_0441.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00442_ScenarioInstanceRandint_id_0442.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00443_ScenarioInstanceRandint_id_0443.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00444_ScenarioInstanceRandint_id_0444.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00445_ScenarioInstanceRandint_id_0445.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00445_ScenarioInstanceRandint_id_0445_shift_on___flight_director_pitch__flight_director_roll.h5 classé comme anomalie.
# ./Dataset/TimeSeries_Scenario_00446_ScenarioInstanceRandint_id_0446.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00447_ScenarioInstanceRandint_id_0447.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00448_ScenarioInstanceRandint_id_0448.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00449_ScenarioInstanceRandint_id_0449.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00450_ScenarioInstanceRandint_id_0450.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00451_ScenarioInstanceRandint_id_0451.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00452_ScenarioInstanceRandint_id_0452.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00453_ScenarioInstanceRandint_id_0453.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00454_ScenarioInstanceRandint_id_0454.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00455_ScenarioInstanceRandint_id_0455.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00456_ScenarioInstanceRandint_id_0456.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00457_ScenarioInstanceRandint_id_0457.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00458_ScenarioInstanceRandint_id_0458.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00459_ScenarioInstanceRandint_id_0459.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00460_ScenarioInstanceRandint_id_0460.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00461_ScenarioInstanceRandint_id_0461.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00462_ScenarioInstanceRandint_id_0462.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00463_ScenarioInstanceRandint_id_0463.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00464_ScenarioInstanceRandint_id_0464.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00465_ScenarioInstanceRandint_id_0465.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00466_ScenarioInstanceRandint_id_0466.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00467_ScenarioInstanceRandint_id_0467.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00468_ScenarioInstanceRandint_id_0468.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00469_ScenarioInstanceRandint_id_0469.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00470_ScenarioInstanceRandint_id_0470.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00471_ScenarioInstanceRandint_id_0471.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00472_ScenarioInstanceRandint_id_0472.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00473_ScenarioInstanceRandint_id_0473.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00474_ScenarioInstanceRandint_id_0474.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00475_ScenarioInstanceRandint_id_0475.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00476_ScenarioInstanceRandint_id_0476.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00477_ScenarioInstanceRandint_id_0477.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00478_ScenarioInstanceRandint_id_0478.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00479_ScenarioInstanceRandint_id_0479.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00480_ScenarioInstanceRandint_id_0480.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00481_ScenarioInstanceRandint_id_0481.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00482_ScenarioInstanceRandint_id_0482.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00483_ScenarioInstanceRandint_id_0483.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00484_ScenarioInstanceRandint_id_0484.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00485_ScenarioInstanceRandint_id_0485.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00486_ScenarioInstanceRandint_id_0486.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00487_ScenarioInstanceRandint_id_0487.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00488_ScenarioInstanceRandint_id_0488.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00489_ScenarioInstanceRandint_id_0489.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00490_ScenarioInstanceRandint_id_0490.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00491_ScenarioInstanceRandint_id_0491.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00492_ScenarioInstanceRandint_id_0492.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00493_ScenarioInstanceRandint_id_0493.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00494_ScenarioInstanceRandint_id_0494.h5 classé comme normal.
# ...
# ./Dataset/TimeSeries_Scenario_00783_ScenarioInstanceRandint_id_0783.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00784_ScenarioInstanceRandint_id_0784.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00785_ScenarioInstanceRandint_id_0785.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00786_ScenarioInstanceRandint_id_0786.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00787_ScenarioInstanceRandint_id_0787.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00788_ScenarioInstanceRandint_id_0788.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00789_ScenarioInstanceRandint_id_0789.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00790_ScenarioInstanceRandint_id_0790.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00791_ScenarioInstanceRandint_id_0791.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00792_ScenarioInstanceRandint_id_0792.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00793_ScenarioInstanceRandint_id_0793.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00794_ScenarioInstanceRandint_id_0794.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00795_ScenarioInstanceRandint_id_0795.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00796_ScenarioInstanceRandint_id_0796.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00797_ScenarioInstanceRandint_id_0797.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00798_ScenarioInstanceRandint_id_0798.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00799_ScenarioInstanceRandint_id_0799.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00800_ScenarioInstanceRandint_id_0800.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00801_ScenarioInstanceRandint_id_0801.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00802_ScenarioInstanceRandint_id_0802.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00803_ScenarioInstanceRandint_id_0803.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00804_ScenarioInstanceRandint_id_0804.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00805_ScenarioInstanceRandint_id_0805.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00806_ScenarioInstanceRandint_id_0806.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00807_ScenarioInstanceRandint_id_0807.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00808_ScenarioInstanceRandint_id_0808.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00809_ScenarioInstanceRandint_id_0809.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00810_ScenarioInstanceRandint_id_0810.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00811_ScenarioInstanceRandint_id_0811.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00812_ScenarioInstanceRandint_id_0812.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00813_ScenarioInstanceRandint_id_0813.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00814_ScenarioInstanceRandint_id_0814.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00815_ScenarioInstanceRandint_id_0815.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00816_ScenarioInstanceRandint_id_0816.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00817_ScenarioInstanceRandint_id_0817.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00818_ScenarioInstanceRandint_id_0818.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00819_ScenarioInstanceRandint_id_0819.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00820_ScenarioInstanceRandint_id_0820.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00821_ScenarioInstanceRandint_id_0821.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00822_ScenarioInstanceRandint_id_0822.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00823_ScenarioInstanceRandint_id_0823.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00824_ScenarioInstanceRandint_id_0824.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00825_ScenarioInstanceRandint_id_0825.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00826_ScenarioInstanceRandint_id_0826.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00827_ScenarioInstanceRandint_id_0827.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00828_ScenarioInstanceRandint_id_0828.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00829_ScenarioInstanceRandint_id_0829.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00830_ScenarioInstanceRandint_id_0830.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00831_ScenarioInstanceRandint_id_0831.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00832_ScenarioInstanceRandint_id_0832.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00833_ScenarioInstanceRandint_id_0833.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00834_ScenarioInstanceRandint_id_0834.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00835_ScenarioInstanceRandint_id_0835.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00836_ScenarioInstanceRandint_id_0836.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00837_ScenarioInstanceRandint_id_0837.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00838_ScenarioInstanceRandint_id_0838.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00839_ScenarioInstanceRandint_id_0839.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00840_ScenarioInstanceRandint_id_0840.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00841_ScenarioInstanceRandint_id_0841.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00842_ScenarioInstanceRandint_id_0842.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00843_ScenarioInstanceRandint_id_0843.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00844_ScenarioInstanceRandint_id_0844.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00845_ScenarioInstanceRandint_id_0845.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00846_ScenarioInstanceRandint_id_0846.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00847_ScenarioInstanceRandint_id_0847.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00848_ScenarioInstanceRandint_id_0848.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00849_ScenarioInstanceRandint_id_0849.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00850_ScenarioInstanceRandint_id_0850.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00851_ScenarioInstanceRandint_id_0851.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00852_ScenarioInstanceRandint_id_0852.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00853_ScenarioInstanceRandint_id_0853.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00854_ScenarioInstanceRandint_id_0854.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00855_ScenarioInstanceRandint_id_0855.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00856_ScenarioInstanceRandint_id_0856.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00857_ScenarioInstanceRandint_id_0857.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00858_ScenarioInstanceRandint_id_0858.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00859_ScenarioInstanceRandint_id_0859.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00860_ScenarioInstanceRandint_id_0860.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00861_ScenarioInstanceRandint_id_0861.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00862_ScenarioInstanceRandint_id_0862.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00863_ScenarioInstanceRandint_id_0863.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00864_ScenarioInstanceRandint_id_0864.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00865_ScenarioInstanceRandint_id_0865.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00866_ScenarioInstanceRandint_id_0866.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00867_ScenarioInstanceRandint_id_0867.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00868_ScenarioInstanceRandint_id_0868.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00869_ScenarioInstanceRandint_id_0869.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00870_ScenarioInstanceRandint_id_0870.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00871_ScenarioInstanceRandint_id_0871.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00872_ScenarioInstanceRandint_id_0872.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00873_ScenarioInstanceRandint_id_0873.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00874_ScenarioInstanceRandint_id_0874.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00875_ScenarioInstanceRandint_id_0875.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00876_ScenarioInstanceRandint_id_0876.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00877_ScenarioInstanceRandint_id_0877.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00877_ScenarioInstanceRandint_id_0877_shift_on___flight_director_pitch__flight_director_roll.h5 classé comme anomalie.
# ./Dataset/TimeSeries_Scenario_00878_ScenarioInstanceRandint_id_0878.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00879_ScenarioInstanceRandint_id_0879.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00880_ScenarioInstanceRandint_id_0880.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00881_ScenarioInstanceRandint_id_0881.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00881_ScenarioInstanceRandint_id_0881_shift_on___flight_director_pitch__flight_director_roll.h5 classé comme anomalie.
# ./Dataset/TimeSeries_Scenario_00882_ScenarioInstanceRandint_id_0882.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00883_ScenarioInstanceRandint_id_0883.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00884_ScenarioInstanceRandint_id_0884.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00885_ScenarioInstanceRandint_id_0885.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00886_ScenarioInstanceRandint_id_0886.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00887_ScenarioInstanceRandint_id_0887.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00888_ScenarioInstanceRandint_id_0888.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00889_ScenarioInstanceRandint_id_0889.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00889_ScenarioInstanceRandint_id_0889_shift_on___flight_director_pitch__flight_director_roll.h5 classé comme anomalie.
# ./Dataset/TimeSeries_Scenario_00890_ScenarioInstanceRandint_id_0890.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00891_ScenarioInstanceRandint_id_0891.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00892_ScenarioInstanceRandint_id_0892.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00893_ScenarioInstanceRandint_id_0893.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00894_ScenarioInstanceRandint_id_0894.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00895_ScenarioInstanceRandint_id_0895.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00896_ScenarioInstanceRandint_id_0896.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00897_ScenarioInstanceRandint_id_0897.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00898_ScenarioInstanceRandint_id_0898.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00899_ScenarioInstanceRandint_id_0899.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00900_ScenarioInstanceRandint_id_0900.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00901_ScenarioInstanceRandint_id_0901.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00902_ScenarioInstanceRandint_id_0902.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00903_ScenarioInstanceRandint_id_0903.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00904_ScenarioInstanceRandint_id_0904.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00905_ScenarioInstanceRandint_id_0905.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00906_ScenarioInstanceRandint_id_0906.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00907_ScenarioInstanceRandint_id_0907.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00908_ScenarioInstanceRandint_id_0908.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00909_ScenarioInstanceRandint_id_0909.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00910_ScenarioInstanceRandint_id_0910.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00910_ScenarioInstanceRandint_id_0910_shift_on___flight_director_pitch__flight_director_roll.h5 classé comme anomalie.
# ./Dataset/TimeSeries_Scenario_00911_ScenarioInstanceRandint_id_0911.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00912_ScenarioInstanceRandint_id_0912.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00913_ScenarioInstanceRandint_id_0913.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00914_ScenarioInstanceRandint_id_0914.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00915_ScenarioInstanceRandint_id_0915.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00916_ScenarioInstanceRandint_id_0916.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00917_ScenarioInstanceRandint_id_0917.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00918_ScenarioInstanceRandint_id_0918.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00919_ScenarioInstanceRandint_id_0919.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00920_ScenarioInstanceRandint_id_0920.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00921_ScenarioInstanceRandint_id_0921.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00922_ScenarioInstanceRandint_id_0922.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00923_ScenarioInstanceRandint_id_0923.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00924_ScenarioInstanceRandint_id_0924.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00925_ScenarioInstanceRandint_id_0925.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00926_ScenarioInstanceRandint_id_0926.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00927_ScenarioInstanceRandint_id_0927.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00928_ScenarioInstanceRandint_id_0928.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00929_ScenarioInstanceRandint_id_0929.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00930_ScenarioInstanceRandint_id_0930.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00931_ScenarioInstanceRandint_id_0931.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00932_ScenarioInstanceRandint_id_0932.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00933_ScenarioInstanceRandint_id_0933.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00934_ScenarioInstanceRandint_id_0934.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00935_ScenarioInstanceRandint_id_0935.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00936_ScenarioInstanceRandint_id_0936.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00937_ScenarioInstanceRandint_id_0937.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00938_ScenarioInstanceRandint_id_0938.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00939_ScenarioInstanceRandint_id_0939.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00940_ScenarioInstanceRandint_id_0940.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00941_ScenarioInstanceRandint_id_0941.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00942_ScenarioInstanceRandint_id_0942.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00943_ScenarioInstanceRandint_id_0943.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00944_ScenarioInstanceRandint_id_0944.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00945_ScenarioInstanceRandint_id_0945.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00946_ScenarioInstanceRandint_id_0946.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00947_ScenarioInstanceRandint_id_0947.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00948_ScenarioInstanceRandint_id_0948.h5 classé comme normal.
# ./Dataset/TimeSeries_Scenario_00949_ScenarioInstanceRandint_id_0949.h5 classé comme normal.

# %%
# Calcul du pourcentage de données normales et anormales
total_files = len(h5_files)
normal_percentage = (len(normal_data_frames) / total_files) * 100 if total_files > 0 else 0
anomaly_percentage = (len(anomaly_data_frames) / total_files) * 100 if total_files > 0 else 0

# Afficher les pourcentages
print(f"Pourcentage de données normales : {normal_percentage:.2f}%")
print(f"Pourcentage de données anormales : {anomaly_percentage:.2f}%")

#nbr de séries temporelles normales 
print(len(normal_data_frames))
print(len(anomaly_data_frames))
# Out:
# Pourcentage de données normales : 96.35%
# Pourcentage de données anormales : 3.65%
# 949
# 36

# %%
normal_data_frames[0].shape
# Out:
# (3582, 135)

# %%
def check_dataframe_sizes(dataframes):
    """
    Vérifie les tailles des DataFrames dans une liste.

    Paramètres:
    - dataframes (list): Liste contenant des DataFrames pandas.

    Retourne:
    - dict: Un dictionnaire où les clés sont les tailles (shape) et les valeurs sont 
            les indices des DataFrames correspondants.
    """
    size_dict = {}
    for i, df in enumerate(dataframes):
        size = df.shape
        if size not in size_dict:
            size_dict[size] = []
        size_dict[size].append(i)
    return size_dict

# %%
# Affichage des tailles de DataFrame
print("Tailles des DataFrames dans normal_data_frames:")
normal_data_sizes = check_dataframe_sizes(normal_data_frames)
for size, indices in normal_data_sizes.items():
    print(f"Taille {size}: {len(indices)} simulations")
# Out:
# Tailles des DataFrames dans normal_data_frames:
# Taille (3582, 135): 559 simulations
# Taille (3583, 135): 341 simulations
# Taille (3584, 135): 35 simulations
# Taille (3581, 135): 13 simulations
# Taille (3585, 135): 1 simulations

# %%
print("Tailles des DataFrames dans anomaly_data_frames:")
anormal_data_sizes = check_dataframe_sizes(anomaly_data_frames)
for size, indices in anormal_data_sizes.items():
    print(f"Taille {size}: {len(indices)} simulations")
# Out:
# Tailles des DataFrames dans anomaly_data_frames:
# Taille (3582, 137): 21 simulations
# Taille (3583, 137): 15 simulations

# %%
# Uniformiser toutes les tailles des DataFrames à (3581, 135)
for i in range(len(normal_data_frames)):
    if normal_data_frames[i].shape[0] > 3581:
        # Supprimer les lignes excédentaires à partir de la fin
        normal_data_frames[i] = normal_data_frames[i].iloc[:3581, :]

for i in range(len(anomaly_data_frames)):
    if anomaly_data_frames[i].shape[0] > 3581:
        # Supprimer les lignes excédentaires à partir de la fin
        anomaly_data_frames[i] = anomaly_data_frames[i].iloc[:3581, :]

# %%
# Affichage des tailles après l'ajustement
print("Tailles des DataFrames dans normal_data_frames après l'ajustement:")
normal_data_sizes = check_dataframe_sizes(normal_data_frames)
for size, indices in normal_data_sizes.items():
    print(f"Taille {size}: {len(indices)} simulations")

print("Tailles des DataFrames dans anomaly_data_frames après l'ajustement:")
anormal_data_sizes = check_dataframe_sizes(anomaly_data_frames)
for size, indices in anormal_data_sizes.items():
    print(f"Taille {size}: {len(indices)} simulations")
# Out:
# Tailles des DataFrames dans normal_data_frames après l'ajustement:
# Taille (3581, 135): 949 simulations
# Tailles des DataFrames dans anomaly_data_frames après l'ajustement:
# Taille (3581, 137): 36 simulations

# %% [markdown]
# ### 1. Prise en main des données et préparation à l'entrainement.

# %% [markdown]
# ### Identifier les colonnes anomalies

# %%
# Comparer les colonnes des DataFrames
def identifier_nouvelles_colonnes(normal_data, anormal_data):
    # Identifier les colonnes qui sont dans anormal_data mais pas dans normal_data
    normal_columns = set(normal_data.columns)
    anormal_columns = set(anormal_data.columns)
    
    nouvelles_colonnes = anormal_columns - normal_columns  # Colonnes présentes dans anormal_data mais pas dans normal_data
    colonnes_manquantes = normal_columns - anormal_columns  # Colonnes présentes dans normal_data mais pas dans anormal_data
    
    print(f"Nombre de nouvelles colonnes dans 'anormal_data' : {len(nouvelles_colonnes)}")
    print(f"Colonnes nouvelles dans 'anormal_data' : {nouvelles_colonnes}")
    print(f"Colonnes manquantes dans 'anormal_data' par rapport à 'normal_data' : {colonnes_manquantes}")
    
    return nouvelles_colonnes

# Exemple d'appel
nouvelles_colonnes = identifier_nouvelles_colonnes(normal_data_frames[0], anomaly_data_frames[0])
# Out:
# Nombre de nouvelles colonnes dans 'anormal_data' : 2
# Colonnes nouvelles dans 'anormal_data' : {'sim/cockpit/autopilot/flight_director_pitch_ground_truth', 'sim/cockpit/autopilot/flight_director_roll_ground_truth'}
# Colonnes manquantes dans 'anormal_data' par rapport à 'normal_data' : set()

# %% [markdown]
# ### Affichage du paramètre présentant l'anomalie vs le normal + Calcul de sa MSE

# %%
from sklearn.metrics import mean_squared_error

def afficher_comparaison_mse_anomalies_et_normaux(anomalie_param1, anomalie_param2, normal_param1, normal_param2, anormal_data):
    # Extraire les colonnes des données anormales et normales
    anormal_1 = anormal_data[anomalie_param1]
    anormal_2 = anormal_data[anomalie_param2]
    normal_1 = anormal_data[normal_param1]
    normal_2 = anormal_data[normal_param2]
    
    
    # Calcul de la MSE entre les paramètres anormaux et normaux 
    mse_1 = mean_squared_error(anormal_1, normal_1)  
    mse_2 = mean_squared_error(anormal_2, normal_2)  
    
    # Affichage des MSE
    print(f"MSE pour {anomalie_param1} vs {normal_param1}: {mse_1:.4f}")
    print(f"MSE pour {anomalie_param2} vs {normal_param2}: {mse_2:.4f}")
    
    # Affichage des courbes
    plt.figure(figsize=(14, 10))
    
    # Comparaison des paramètres anormaux vs normaux
    plt.subplot(2, 1, 1)
    plt.plot(anormal_1[:1000], label=f'{anomalie_param1} (Anomalie)', color='red', alpha=0.7)
    plt.plot(normal_1[:1000], label=f'{normal_param1} (Normal)', color='blue', alpha=0.7)
    plt.title(f"Comparaison {anomalie_param1} vs {normal_param1}")
    plt.legend()
    plt.xlabel("Index")
    plt.ylabel("Valeur")
    
    plt.subplot(2, 1, 2)
    plt.plot(anormal_2[:1000], label=f'{anomalie_param2} (Anomalie)', color='red', alpha=0.7)
    plt.plot(normal_2[:1000], label=f'{normal_param2} (Normal)', color='blue', alpha=0.7)
    plt.title(f"Comparaison {anomalie_param2} vs {normal_param2}")
    plt.legend()
    plt.xlabel("Index")
    plt.ylabel("Valeur")
    
    # Affichage global
    plt.tight_layout()
    plt.show()

# Exemple d'appel de la fonction
afficher_comparaison_mse_anomalies_et_normaux(
    'sim/cockpit/autopilot/flight_director_roll', 
    'sim/cockpit/autopilot/flight_director_pitch',
    'sim/cockpit/autopilot/flight_director_roll_ground_truth',
    'sim/cockpit/autopilot/flight_director_pitch_ground_truth',
    anomaly_data_frames[0]
)
# Out:
# MSE pour sim/cockpit/autopilot/flight_director_roll vs sim/cockpit/autopilot/flight_director_roll_ground_truth: 0.0003
# MSE pour sim/cockpit/autopilot/flight_director_pitch vs sim/cockpit/autopilot/flight_director_pitch_ground_truth: 8.0559

# %%
# Colonnes à supprimer
columns_to_drop = [
    'sim/cockpit/autopilot/flight_director_roll_ground_truth',
    'sim/cockpit/autopilot/flight_director_pitch_ground_truth'
]

# Suppression des colonnes des DataFrames dans anomaly_data_frames
for i in range(len(anomaly_data_frames)):
    anomaly_data_frames[i] = anomaly_data_frames[i].drop(columns=columns_to_drop, errors='ignore')

# %%
print("Tailles des DataFrames dans anomaly_data_frames après l'ajustement:")
anormal_data_sizes = check_dataframe_sizes(anomaly_data_frames)
for size, indices in anormal_data_sizes.items():
    print(f"Taille {size}: {len(indices)} simulations")
# Out:
# Tailles des DataFrames dans anomaly_data_frames après l'ajustement:
# Taille (3581, 135): 36 simulations

# %% [markdown]
# ### Préparation des données

# %%
# Diviser les données normales en ensemble d'entraînement (80%) et ensemble de test (20%)
train_normal, test_normal = train_test_split(normal_data_frames, test_size=0.2, random_state=42)

# Les données anormales seront utilisées comme ensemble de test
test_anomaly = anomaly_data_frames

# %%
# Fonction pour normaliser et convertir les DataFrames en tableau numpy
def prepare_data(dataframes):
    """
    Prépare les données pour le modèle LSTM:
    - Convertit les DataFrames en tableaux numpy.
    - Normalise les valeurs avec StandardScaler.

    Paramètres:
    - dataframes (list): Liste de DataFrames.

    Retourne:
    - numpy.array: Données normalisées sous forme de tableau numpy.
    """
    scaler = MinMaxScaler()
    # Convertir les DataFrames en tableau numpy et normaliser
    data_array = [df.values for df in dataframes]
    data_array = np.array([scaler.fit_transform(simulation) for simulation in data_array])
    return np.array(data_array)

# Normalisation et conversion des données
train_normal_data = prepare_data(train_normal)
test_normal_data = prepare_data(test_normal)
test_anomaly_data = prepare_data(test_anomaly)

print(f"Taille des données d'entraînement: {train_normal_data.shape}")
print(f"Taille des données de test (normal): {test_normal_data.shape}")
print(f"Taille des données de test (anormal): {test_anomaly_data.shape}")
# Out:
# Taille des données d'entraînement: (759, 3581, 135)
# Taille des données de test (normal): (190, 3581, 135)
# Taille des données de test (anormal): (36, 3581, 135)

# %%
# Créer un axe de temps (0 à 3580)
timesteps = range(train_normal_data.shape[1])

# Tracer les données
plt.figure(figsize=(12, 6))
plt.plot(timesteps, train_normal_data[0, :, 0], label="Variable avant downsampling", color='b')
plt.title("Visualisation données avant downsampling")
plt.xlabel("Timesteps")
plt.ylabel("Valeurs")
plt.legend()
plt.grid(True)
plt.show()

# %%
# Fonction pour effectuer le downsampling des données
def downsample(data, factor=3):
    """
    Réduit le nombre d'étapes temporelles en gardant chaque `factor`-ème étape.

    Paramètres:
    - data (numpy.array): Tableau de données avec la forme (samples, timesteps, features).
    - factor (int): Facteur de downsampling (par défaut 3).

    Retourne:
    - numpy.array: Données après downsampling.
    """
    return data[:, ::factor, :]  # Garder chaque `factor`-ème étape

# %%
# Appliquer le downsampling aux données normalisées et renommer les variables
train_normal_data_reduced = downsample(train_normal_data)
test_normal_data_reduced = downsample(test_normal_data)
test_anomaly_data_reduced = downsample(test_anomaly_data)

# Affichage des tailles des données après préparation et downsampling
print(f"Taille des données d'entraînement réduites: {train_normal_data_reduced.shape}")
print(f"Taille des données de test normales réduites: {test_normal_data_reduced.shape}")
print(f"Taille des données de test anormales réduites: {test_anomaly_data_reduced.shape}")
# Out:
# Taille des données d'entraînement réduites: (759, 1194, 135)
# Taille des données de test normales réduites: (190, 1194, 135)
# Taille des données de test anormales réduites: (36, 1194, 135)

# %%
timesteps = range(train_normal_data_reduced.shape[1])

# Tracer les données
plt.figure(figsize=(12, 6))
plt.plot(timesteps, train_normal_data_reduced[0, :, 0], label="Variable réduite", color='b')
plt.title("Visualisation données reduites")
plt.xlabel("Timesteps")
plt.ylabel("Valeurs")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ### Construction du modèle LSTM Autoencoder

# %%
# Dimensions des données
timesteps = train_normal_data_reduced.shape[1]  # Nombre d'étapes temporelles après downsampling
input_dim = train_normal_data_reduced.shape[2]  # Nombre de variables (features)

# Définir l'architecture du modèle LSTM Autoencoder
inputs = Input(shape=(timesteps, input_dim))

# LSTM Layers
encoded = tf.keras.layers.LSTM(128, activation='tanh', return_sequences=True)(inputs)
encoded = tf.keras.layers.LSTM(64, activation='tanh', return_sequences=False)(encoded)

# Bottleneck
bottleneck = tf.keras.layers.Dense(32, activation='relu')(encoded)

# Decoder
decoded = tf.keras.layers.RepeatVector(timesteps)(bottleneck)
decoded = tf.keras.layers.LSTM(64, activation='tanh', return_sequences=True)(decoded)
decoded = tf.keras.layers.LSTM(128, activation='tanh', return_sequences=True)(decoded)
outputs = tf.keras.layers.TimeDistributed(tf.keras.layers.Dense(135))(decoded)

# %%
# Compile the model
autoencoder = tf.keras.Model(inputs, outputs)
autoencoder.compile(optimizer='adam', loss='mse')

# %%
# Entraîner le modèle
with tf.device('/GPU:0'):
    history = autoencoder.fit(
        train_normal_data, train_normal_data,
        epochs=5,
        batch_size=16,
        validation_data=(test_normal_data, test_normal_data),
        shuffle=True
    )

# %% [markdown]
# ### Détection des anomalies

# %%
# Prédire les données de test
test_normal_pred = autoencoder.predict(test_normal_data)
test_anomaly_pred = autoencoder.predict(test_anomaly_data)

# Calculer l'erreur de reconstruction (MSE - Mean Squared Error)
normal_reconstruction_error = np.mean(np.square(test_normal_data - test_normal_pred), axis=(1, 2))
anomaly_reconstruction_error = np.mean(np.square(test_anomaly_data - test_anomaly_pred), axis=(1, 2))

# Définir le seuil basé sur les données normales (95e percentile)
threshold = np.percentile(normal_reconstruction_error, 95)
print(f"Seuil pour détecter les anomalies: {threshold}")

# Identifier les anomalies
test_normal_anomalies = normal_reconstruction_error > threshold
test_anomaly_anomalies = anomaly_reconstruction_error > threshold

# Afficher les résultats
print(f"Nombre d'anomalies détectées dans le test normal: {np.sum(test_normal_anomalies)} / {len(test_normal_anomalies)}")
print(f"Nombre d'anomalies détectées dans le test anormal: {np.sum(test_anomaly_anomalies)} / {len(test_anomaly_anomalies)}")

# %% [markdown]
# ### Visualisation des résultats

# %%
# Visualiser la distribution des erreurs de reconstruction
plt.figure(figsize=(10, 6))
plt.hist(normal_reconstruction_error, bins=50, alpha=0.6, label='Données normales')
plt.hist(anomaly_reconstruction_error, bins=50, alpha=0.6, label='Données anormales')
plt.axvline(threshold, color='red', linestyle='--', label='Seuil')
plt.title('Distribution des erreurs de reconstruction')
plt.xlabel('Erreur de reconstruction')
plt.ylabel('Fréquence')
plt.legend()
plt.show()
